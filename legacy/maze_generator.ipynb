# %%
import random
import math
import numpy as np
from math import sqrt

# Find number of surrounding cells
def surroundingCells(rand_wall):
    s_cells = 0
    if (thegrid[rand_wall[0]-1][rand_wall[1]] == '.'):
        s_cells += 1
    if (thegrid[rand_wall[0]+1][rand_wall[1]] == '.'):
        s_cells += 1
    if (thegrid[rand_wall[0]][rand_wall[1]-1] == '.'):
        s_cells +=1
    if (thegrid[rand_wall[0]][rand_wall[1]+1] == '.'):
        s_cells += 1
    return s_cells

def printthegrid(thegrid):
    for i in range(0, gridy):
        for j in range(0, gridx):
            if (thegrid[i][j] == 'u'):
                print(str(thegrid[i][j]), end="   ")
            elif (thegrid[i][j] == 'c'):
                print(str(thegrid[i][j]), end="   ")
            else:
                print(str(thegrid[i][j]), end="   ")
        print('\n')

#Initial Variables, You can change these
gridx = 10
gridy = 10

height = gridx
width = gridy

obstaclepercent = 40

#amount of obstacles
obstacleamount = math.floor((((gridx * gridy) - 2) * (obstaclepercent/100)))

#symbols
symbolstart = 'S'
symbolend = 'G'
symbolopen = '.'
symbolobstacle = 'H'

unvisited = 'u'

def euclidean_distance(p1, p2):
    return sqrt((p1[0]-p2[0])**2+(p1[1]-p2[1])**2)

#randomise start and end
def randomcoord():
    return (random.randint(0, gridx-1), random.randint(0, gridy-1))

#start and end location
start = randomcoord()
end = randomcoord()
#if the start and end location are the same
while start == end or euclidean_distance(start, end) < min(gridx, gridy)/2:
    end = randomcoord()
    
print(euclidean_distance(start, end))

#start = (6, 9)
#end = (4, 5)

#start = (5, 3)
#end = (7, 8)

#solution path
solutionpath = list(tuple())

#if the goal is near the solution
flag = False
if start[0] == end[0]:
    if end[1] > 0:
        if start[1] == (end[1] + 1):
            flag = True
    if end[1] < gridy:
        if start[1] == (end[1] - 1):
            flag = True
if start[1] == end[1]: 
    if end[0] > 0:
        if start[0] == (end[0] + 1):
            flag = True
    if end[0] < gridx:
        if start[0] == (end[0] - 1):
            flag = True
            
            
# finds a solution path. simple rightangled approach
if flag == False:
    if start[0] < end[0]:
        for x in range(start[0]+1,end[0]+1):
            solutionpath.append((x,start[1]))
    else:
        for x in range(start[0]-1,end[0]-1,-1):
            solutionpath.append((x,start[1]))
    if abs(start[1] - end[1]) >= 1:
        if start[1] < end[1]: 
            for y in range(start[1],end[1]-1):
                solutionpath.append((end[0],y+1))
        else:
            for y in range(start[1],end[1]+1,-1):
                solutionpath.append((end[0],y-1))
                
    else:
        solutionpath = solutionpath[:-1]
            


    
#defining the grid and adding the start/end
thegrid = [[unvisited]*gridy for i in range(gridx)]    
thegrid[start[0]][start[1]] = symbolstart
thegrid[end[0]][end[1]] = symbolend



#defining solution path
for coord in solutionpath:
    thegrid[coord[0]][coord[1]] = '*' 
    

thegrid = [['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u'],
 ['u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u', 'u']]
    
# starting_height = int(random.random()*gridx)
# starting_width = int(random.random()*gridy)
starting_height = 3
starting_width = 3


if (starting_height == 0):
    starting_height += 1
if (starting_height == height-1):
    starting_height -= 1
if (starting_width == 0):
    starting_width += 1
if (starting_width == width-1):
    starting_width -= 1

thegrid[starting_height][starting_width] = symbolopen
walls = []
walls.append([starting_height - 1, starting_width])
walls.append([starting_height, starting_width - 1])
walls.append([starting_height, starting_width + 1])
walls.append([starting_height + 1, starting_width])
    

# Denote walls in thegrid
thegrid[starting_height-1][starting_width] = symbolobstacle
thegrid[starting_height][starting_width - 1] = symbolobstacle
thegrid[starting_height][starting_width + 1] = symbolobstacle
thegrid[starting_height + 1][starting_width] = symbolobstacle

while (walls):
    # Pick a random wall
    rand_wall = walls[int(random.random()*len(walls))-1]
    
    # Check if it is a left wall
    if (rand_wall[1] != 0):
        if (thegrid[rand_wall[0]][rand_wall[1]-1] == 'u' and thegrid[rand_wall[0]][rand_wall[1]+1] == '.'):
        # Find the number of surrounding cells
            s_cells = surroundingCells(rand_wall)

            if (s_cells < 2):
                # Denote the new path
                thegrid[rand_wall[0]][rand_wall[1]] = '.'

                # Mark the new walls
                # Upper cell
                if (rand_wall[0] != 0):
                    if (thegrid[rand_wall[0]-1][rand_wall[1]] != '.'):
                        thegrid[rand_wall[0]-1][rand_wall[1]] = 'H'
                    if ([rand_wall[0]-1, rand_wall[1]] not in walls):
                        walls.append([rand_wall[0]-1, rand_wall[1]])


                # Bottom cell
                if (rand_wall[0] != height-1):
                    if (thegrid[rand_wall[0]+1][rand_wall[1]] != '.'):
                        thegrid[rand_wall[0]+1][rand_wall[1]] = 'H'
                    if ([rand_wall[0]+1, rand_wall[1]] not in walls):
                        walls.append([rand_wall[0]+1, rand_wall[1]])

                # Leftmost cell
                if (rand_wall[1] != 0):	
                    if (thegrid[rand_wall[0]][rand_wall[1]-1] != '.'):
                        thegrid[rand_wall[0]][rand_wall[1]-1] = 'H'
                    if ([rand_wall[0], rand_wall[1]-1] not in walls):
                        walls.append([rand_wall[0], rand_wall[1]-1])
            

            # Delete wall
            for wall in walls:
                if (wall[0] == rand_wall[0] and wall[1] == rand_wall[1]):
                    walls.remove(wall)

            continue


    # Check if it is an upper wall
    if (rand_wall[0] != 0):
        if (thegrid[rand_wall[0]-1][rand_wall[1]] == 'u' and thegrid[rand_wall[0]+1][rand_wall[1]] == '.'):

            s_cells = surroundingCells(rand_wall)
            if (s_cells < 2):
                # Denote the new path
                thegrid[rand_wall[0]][rand_wall[1]] = '.'

                # Mark the new walls
                # Upper cell
                if (rand_wall[0] != 0):
                    if (thegrid[rand_wall[0]-1][rand_wall[1]] != '.'):
                        thegrid[rand_wall[0]-1][rand_wall[1]] = 'H'
                    if ([rand_wall[0]-1, rand_wall[1]] not in walls):
                        walls.append([rand_wall[0]-1, rand_wall[1]])

                # Leftmost cell
                if (rand_wall[1] != 0):
                    if (thegrid[rand_wall[0]][rand_wall[1]-1] != '.'):
                        thegrid[rand_wall[0]][rand_wall[1]-1] = 'H'
                    if ([rand_wall[0], rand_wall[1]-1] not in walls):
                        walls.append([rand_wall[0], rand_wall[1]-1])

                # Rightmost cell
                if (rand_wall[1] != width-1):
                    if (thegrid[rand_wall[0]][rand_wall[1]+1] != '.'):
                        thegrid[rand_wall[0]][rand_wall[1]+1] = 'H'
                    if ([rand_wall[0], rand_wall[1]+1] not in walls):
                        walls.append([rand_wall[0], rand_wall[1]+1])

            # Delete wall
            for wall in walls:
                if (wall[0] == rand_wall[0] and wall[1] == rand_wall[1]):
                    walls.remove(wall)

            continue
            
    # Check the bottom wall
    if (rand_wall[0] != height-1):
        if (thegrid[rand_wall[0]+1][rand_wall[1]] == 'u' and thegrid[rand_wall[0]-1][rand_wall[1]] == '.'):

            s_cells = surroundingCells(rand_wall)
            if (s_cells < 2):
                # Denote the new path
                thegrid[rand_wall[0]][rand_wall[1]] = '.'

                # Mark the new walls
                if (rand_wall[0] != height-1):
                    if (thegrid[rand_wall[0]+1][rand_wall[1]] != '.'):
                        thegrid[rand_wall[0]+1][rand_wall[1]] = 'H'
                    if ([rand_wall[0]+1, rand_wall[1]] not in walls):
                        walls.append([rand_wall[0]+1, rand_wall[1]])
                if (rand_wall[1] != 0):
                    if (thegrid[rand_wall[0]][rand_wall[1]-1] != '.'):
                        thegrid[rand_wall[0]][rand_wall[1]-1] = 'H'
                    if ([rand_wall[0], rand_wall[1]-1] not in walls):
                        walls.append([rand_wall[0], rand_wall[1]-1])
                if (rand_wall[1] != width-1):
                    if (thegrid[rand_wall[0]][rand_wall[1]+1] != '.'):
                        thegrid[rand_wall[0]][rand_wall[1]+1] = 'H'
                    if ([rand_wall[0], rand_wall[1]+1] not in walls):
                        walls.append([rand_wall[0], rand_wall[1]+1])

            # Delete wall
            for wall in walls:
                if (wall[0] == rand_wall[0] and wall[1] == rand_wall[1]):
                    walls.remove(wall)


            continue
            
    # Check the right wall
    if (rand_wall[1] != width-1):
        if (thegrid[rand_wall[0]][rand_wall[1]+1] == 'u' and thegrid[rand_wall[0]][rand_wall[1]-1] == '.'):

            s_cells = surroundingCells(rand_wall)
            if (s_cells < 2):
                # Denote the new path
                thegrid[rand_wall[0]][rand_wall[1]] = '.'

                # Mark the new walls
                if (rand_wall[1] != width-1):
                    if (thegrid[rand_wall[0]][rand_wall[1]+1] != '.'):
                        thegrid[rand_wall[0]][rand_wall[1]+1] = 'H'
                    if ([rand_wall[0], rand_wall[1]+1] not in walls):
                        walls.append([rand_wall[0], rand_wall[1]+1])
                if (rand_wall[0] != height-1):
                    if (thegrid[rand_wall[0]+1][rand_wall[1]] != '.'):
                        thegrid[rand_wall[0]+1][rand_wall[1]] = 'H'
                    if ([rand_wall[0]+1, rand_wall[1]] not in walls):
                        walls.append([rand_wall[0]+1, rand_wall[1]])
                if (rand_wall[0] != 0):	
                    if (thegrid[rand_wall[0]-1][rand_wall[1]] != '.'):
                        thegrid[rand_wall[0]-1][rand_wall[1]] = 'H'
                    if ([rand_wall[0]-1, rand_wall[1]] not in walls):
                        walls.append([rand_wall[0]-1, rand_wall[1]])

            # Delete wall
            for wall in walls:
                if (wall[0] == rand_wall[0] and wall[1] == rand_wall[1]):
                    walls.remove(wall)

            continue
            
    # Delete the wall from the list anyway
    for wall in walls:
        if (wall[0] == rand_wall[0] and wall[1] == rand_wall[1]):
            walls.remove(wall)
            
# finds a solution path. simple rightangled approach
if flag == False:
    if start[0] < end[0]:
        for x in range(start[0]+1,end[0]+1):
            solutionpath.append((x,start[1]))
    else:
        for x in range(start[0]-1,end[0]-1,-1):
            solutionpath.append((x,start[1]))
    if abs(start[1] - end[1]) >= 1:
        if start[1] < end[1]: 
            for y in range(start[1],end[1]-1):
                solutionpath.append((end[0],y+1))
        else:
            for y in range(start[1],end[1]+1,-1):
                solutionpath.append((end[0],y-1))
                
    else:
        solutionpath = solutionpath[:-1]
            


    
#defining the grid and adding the start/end
thegrid[start[0]][start[1]] = symbolstart
thegrid[end[0]][end[1]] = symbolend



#defining solution path
for coord in solutionpath:
    thegrid[coord[0]][coord[1]] = '*' 
    

# Mark the remaining unvisited cells as walls
for i in range(0, gridy):
    for j in range(0, gridx):
        if (thegrid[i][j] == 'u'):
            thegrid[i][j] = symbolobstacle
        if (thegrid[i][j] == '*'):
            thegrid[i][j] = symbolopen
            
# prints grid
printthegrid(thegrid)
# Out:
# 5.0
# H   H   H   H   H   H   H   H   H   H
#
# H   .   H   .   H   S   H   .   .   H
#
# H   .   .   .   .   .   .   .   H   H
#
# H   H   H   .   H   .   H   H   H   H
#
# H   .   .   .   H   .   H   H   .   H
#
# H   .   H   .   H   .   .   .   G   H
#
# H   .   H   H   H   .   H   .   H   H
#
# H   .   .   H   H   .   H   .   H   H
#
# H   .   H   H   .   .   H   .   .   H
#
# H   H   H   H   H   H   H   H   H   H
